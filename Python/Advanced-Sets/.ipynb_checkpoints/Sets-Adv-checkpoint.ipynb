# %%
s = set()

# %%
s.add(1)
s
# Out:
# {1, 2}

# %%
s.add(2)
s
# Out:
# {1, 2}

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s = {1,2,3}

# %%
s
# Out:
# {1, 2, 3}

# %%
sc = s.copy()

# %%
sc.add(61)

# %%
sc
# Out:
# {1, 2, 3, 61}

# %%
s
# Out:
# {1, 2, 3}

# %%
s.difference(sc)
# Out:
# set()

# %%
sc.difference(s)
# Out:
# {61}

# %%
# set1.difference_update(set2)

# %%
s1 = {1,2,3}

# %%
s2 = {1,4,5}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s
# Out:
# {1, 2, 3}

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 3, 4}

# %%
s.discard(14)

# %%
s
# Out:
# {1, 3, 4}

# %%
s1 = {1,2,3}
s2 = {1,2,4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1 = {1,2}
s2 = {1,2,4}
s3 = {5}

# %%
# return true if null intersection

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.issubset(s2)
# Out:
# True

# %%
s2.issubset(s1)
# Out:
# False

# %%
s2.issuperset(s1)
# Out:
# True

# %%
# symmetricc difference: it's only the element not common (INtersection's opposite)

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.symmetric_difference(s2)
# Out:
# {4}

# %%
s1
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.union(s2)
# Out:
# {1, 2, 4}

# %%
s1.update(s2)

# %%
s1
# Out:
# {1, 2, 4}
